# %%
import os
import numpy as np
import re
import shutil
import tensorflow as tf
import gensim.downloader as api

# %%
DATA_DIR = './data'
CHECKPOINT_DIR = os.path.join(DATA_DIR, "checkpoints")

# %%
def download_and_read(urls):
    texts =[]
    for i, url in enumerate(urls):
        p = tf.keras.utils.get_file("ex1-{:d}.txt".format(i), url, cache_dir = ".")
        text = open(p, "r", encoding = 'utf-8').read()
        #remove byte order mark
        text = text.replace("\ufeff", "")
        #remove newlines
        text = text.replace("\n", " ")
        text = re.sub(r'\s+', ' ', text)
        texts.extend(text)
    return texts

# %%
texts = download_and_read(["http://www.gutenberg.org/cache/epub/28885/pg28885.txt",
 "https://www.gutenberg.org/files/12/12-0.txt"
])

# %%
vocab = sorted(set(texts))
print("vocab size: {:d}".format(len(vocab)))

char2idx = {c:i for i,c in enumerate(vocab)}
idx2char = {i:c for c,i in char2idx.items()}
# Out:
# vocab size: 92

# %%
texts_as_ints = np.array([char2idx[c] for c in texts])
data = tf.data.Dataset.from_tensor_slices(texts_as_ints)

# number of characters to show before asking for prediction
#sequences: [None, 100]
seq_length = 100
sequences = data.batch(seq_length+1, drop_remainder = True)

# %%
# EMBEDDING_MODEL = api.load('glove-wiki-gigaword-300')

# %%
# def build_embedding_matrix(EMBEDDING_MODEL, word2idx, EMBEDDING_DIM):
#     E = np.zeros((len(vocab), EMBEDDING_DIM))
#     for word, idx in word2idx.items():
#         try:
#             E[idx] = EMBEDDING_MODEL.word_vec(word)
#         except KeyError:
#             pass
#     return E

# %%
# E = build_embedding_matrix(EMBEDDING_MODEL, char2idx,300)

# %%
def split_train_labels(sequences):
    input_seq = sequences[0:-1]
    output_seq = sequences[1:]
    return input_seq, output_seq

# %%
sequences = sequences.map(split_train_labels)

# %%
for input_seq, output_seq in sequences.take(1):
    print("input:[{:s}]".format("".join([idx2char[i] for i in input_seq.numpy()])))
    print("output:[{:s}]".format("".join([idx2char[i] for i in output_seq.numpy()])))
    print(input_seq.shape)
# Out:
# input:[Project Gutenberg's Alice's Adventures in Wonderland, by Lewis Carroll This eBook is for the use of ]
# output:[roject Gutenberg's Alice's Adventures in Wonderland, by Lewis Carroll This eBook is for the use of a]
# (100,)

# %%
#set up for training
#batches: [None, 64, 100]
batch_size = 64
steps_per_epochs = len(texts) // batch_size // seq_length
dataset = sequences.shuffle(10000).batch(batch_size, drop_remainder = True)

# %%
class CharGenModel(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, num_timesteps, rnn_output_dim, **kwargs):
        super(CharGenModel, self).__init__(**kwargs)
        self.embedding_layer = tf.keras.layers.Embedding(
            vocab_size,
            embedding_dim,
#             input_length = seq_length,
#             weights = [E],
#             trainable = False
        )
        self.rnn_layer = tf.keras.layers.GRU(
            rnn_output_dim,
            recurrent_initializer = "glorot_uniform",
            recurrent_activation = 'sigmoid',
            stateful = True,
            return_sequences = True
        )
        self.dense_layer = tf.keras.layers.Dense(vocab_size)
        
    def call(self, x):
        x = self.embedding_layer(x)
        x = self.rnn_layer(x)
        x = self.dense_layer(x)
        return x

# %%
vocab_size = len(vocab)
embedding_dim = 256
rnn_output_dim = 100

model = CharGenModel(vocab_size, embedding_dim, seq_length, rnn_output_dim)
model.build(input_shape = (batch_size, seq_length))

# %%
def loss(labels, predictions):
    return tf.losses.sparse_categorical_crossentropy(labels, predictions, from_logits = True,)

# %%
model.compile(optimizer = tf.optimizers.Adam(), loss = loss)

# %%
def generate_text(model, prefix_string, char2idx, idx2char,num_chars_to_generate=1000, temperature=1.0):
    inpuT = [char2idx[s] for s in prefix_string]
    inpuT = tf.expand_dims(inpuT, 0)
    text_generated = []
    model.reset_states()
    for i in range(num_chars_to_generate):
        preds = model(inpuT)
        preds = tf.squeeze(preds, 0) / temperature
        # predict char returned by model
        pred_id = tf.random.categorical(
        preds, num_samples=1)[-1, 0].numpy()
        text_generated.append(idx2char[pred_id])
        # pass the prediction as the next input to the model
        inpuT = tf.expand_dims([pred_id], 0)
    return prefix_string + "".join(text_generated)

# %%
# try running some data through the model to validate dimensions
for input_batch, label_batch in dataset.take(1):
    pred_batch = model(input_batch)

print(pred_batch.shape)
assert(pred_batch.shape[0] == batch_size)
assert(pred_batch.shape[1] == seq_length)
assert(pred_batch.shape[2] == vocab_size)
# Out:
# (64, 100, 92)

# %%
epochs = 100
callbacks = [tf.keras.callbacks.TensorBoard(log_dir = './logs')]
for i in range(epochs//10):
    model.fit(dataset.repeat(), epochs = 10, steps_per_epoch = steps_per_epochs,
#              callbacks = [checkpoint_callback, tensorboard_callback]
              callbacks = callbacks
             )
    checkpoint_file = os.path.join(CHECKPOINT_DIR, "model_epoch_{:d}".format(i+1))
    model.save_weights(checkpoint_file)
    
    #create generative model using the trained model so far
    gen_model = CharGenModel(vocab_size, embedding_dim, seq_length, rnn_output_dim)
    gen_model.load_weights(checkpoint_file)
    gen_model.build(input_shape = (1, seq_length))
    
    print("after epoch: {:d}".format(i+1))
    print(generate_text(gen_model, "Alice", char2idx, idx2char))
    print("-"*15)
# Out:
# Epoch 1/10
# 54/54 [==============================] - 5s 71ms/step - loss: 3.5281
# Epoch 2/10
# 54/54 [==============================] - 3s 61ms/step - loss: 2.7578
# Epoch 3/10
# 54/54 [==============================] - 3s 60ms/step - loss: 2.4771
# Epoch 4/10
# 54/54 [==============================] - 3s 60ms/step - loss: 2.3358
# Epoch 5/10
# 54/54 [==============================] - 3s 57ms/step - loss: 2.2278
# Epoch 6/10
# 54/54 [==============================] - 3s 61ms/step - loss: 2.1425
# Epoch 7/10
# 54/54 [==============================] - 3s 57ms/step - loss: 2.0595
# Epoch 8/10
# 54/54 [==============================] - 3s 59ms/step - loss: 1.9952
# Epoch 9/10
# 54/54 [==============================] - 3s 57ms/step - loss: 1.9361
# Epoch 10/10
# 54/54 [==============================] - 3s 55ms/step - loss: 1.8907
# after epoch: 1
# Alice wering wopink one a spyillashinglate-diss. The Rey gor a crould comy thes sunded exeelf tlech cause bdearuteled shat fruy squri‘_ch” ellf and likesle atiol trees ewave got _Alice cang lyok a lous aght it hild marge at lance Gut!" Bo said you Re Queen so portes, I sint hathed how youmed dattinn a axpoor sookn. thut wase shemer freagars. 5'ND_Y R@BGpU TCElCYo7 Tucectruck:-" sars amse I readd in!” stoten Soow. Than a mibutes," "Alice_ I caning her of to _to seectoin a kent of gen aid dewnown farg get of thimall the bogake ufpy Lictiemally” samly Oniinting moprargh a prowntsmou popsely dave tildly arraid the avp!” “zese a make a marragwise. bf. In wancectowh; the Plokn out to “1.Bat, way be, the llas giter waspisilring one munse jurcaind bot,_ is with at mare eclose: "Haint, “and the radeen.”: Hake ‘I that sas to trealf rojecting." [Queen Ouc! Reat it slict. “and," “_quice sull; no wand: "“as of? but I my_ to makn’tel-" I the onn the Mock said gestore thingaw a vo boe for get a many amadi
# ---------------
# Epoch 1/10
# 54/54 [==============================] - 4s 66ms/step - loss: 1.8472
# Epoch 2/10
# 54/54 [==============================] - 3s 57ms/step - loss: 1.8115
# Epoch 3/10
# 54/54 [==============================] - 3s 59ms/step - loss: 1.7730
# Epoch 4/10
# 54/54 [==============================] - 3s 58ms/step - loss: 1.7441
# Epoch 5/10
# 54/54 [==============================] - 3s 57ms/step - loss: 1.7211
# Epoch 6/10
# 54/54 [==============================] - 3s 57ms/step - loss: 1.6973
# Epoch 7/10
# 54/54 [==============================] - 3s 57ms/step - loss: 1.6709
# Epoch 8/10
# 54/54 [==============================] - 3s 55ms/step - loss: 1.6568
# Epoch 9/10
# 54/54 [==============================] - 3s 58ms/step - loss: 1.6346
# Epoch 10/10
# 54/54 [==============================] - 3s 56ms/step - loss: 1.6215
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).embedding_layer.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).dense_layer.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).dense_layer.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).rnn_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).rnn_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).rnn_layer.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).embedding_layer.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).dense_layer.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).dense_layer.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).rnn_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).rnn_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).rnn_layer.cell.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# after epoch: 2
# Alice very taid you saidutir Lowe treed, justimbled of the briscain’t datting do been eye wene; so muts replited.. "Welent!" and ma‘dich_," said dish to the pate making it to of the Mock “How of ever and lambus to fou more eit you wing hath it was postling, enojed at vala inting time to had suten’t eyes took when sof they dreasn offegais way ense Dimphing, thich with you, at rapponly looking steep ewas juar. I leiving whope!” Alice was very my one’t wistile make and here heins bouse," the Bome and up that wairge _would_ spinded way that she weave that was a chleg day.-H Parching about it,” ase the While’s ohe it seeper, ass, Alice shander the hable, "Well adrack, just her that dains, emsain and hill, and this percarked, nesher: ‘Why spart only to cut this _areshionly to the fividned I shouldnce sS off, "Enppioush it she houdd _at dishe! If this agaid. "Pach was and biting the little gan to it wenting that Butter Arild,” and haven in to hand a that hur from the minice a from her surked insen
# ---------------
# Epoch 1/10
# 54/54 [==============================] - 4s 70ms/step - loss: 1.6043
# Epoch 2/10
# 54/54 [==============================] - 3s 57ms/step - loss: 1.5914
# Epoch 3/10
# 54/54 [==============================] - 3s 55ms/step - loss: 1.5784
# Epoch 4/10
# 54/54 [==============================] - 3s 56ms/step - loss: 1.5633
# Epoch 5/10
# 54/54 [==============================] - 3s 59ms/step - loss: 1.5522
# Epoch 6/10
# 54/54 [==============================] - 3s 57ms/step - loss: 1.5443
# Epoch 7/10
# 54/54 [==============================] - 3s 58ms/step - loss: 1.5293
# Epoch 8/10
# 54/54 [==============================] - 3s 57ms/step - loss: 1.5229
# Epoch 9/10
# 54/54 [==============================] - 3s 56ms/step - loss: 1.5159
# Epoch 10/10
# 54/54 [==============================] - 3s 56ms/step - loss: 1.5023
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).embedding_layer.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).dense_layer.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).dense_layer.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).rnn_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).rnn_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).rnn_layer.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).embedding_layer.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).dense_layer.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).dense_layer.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).rnn_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).rnn_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).rnn_layer.cell.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# after epoch: 3
# Alice. What's knd be another lates off," said go on the sarding beess, and sake at yon't they iss, and stood!" 7ad the Project Gutenbe's Doon, she talans 24 Quatter were began backs e inthing over flaut things the King. “What read his stroper Sermass whick on how in a back dished heargrash went, she smakied you’ll every again a go had not herself copying," said Alice: the Caterphily suepfortant all Ahister of the two way cale botely, “in the barch as the Queen time, when she dish in him for drimping him. One oby to Parch-” “Inain, Mar_. “On," Queen. “Is, In your ever maid!- know. Suver I did _cQuee_. "POwactedly, as if she was just it to a brease old hardleour eady-pporsion—or, she go her openwarks (Anl rates to: he sail in a lon lensain,” ald chooge, and their dears of the bokestan eather, "The Poots the cadibe; that she remarked. "Not taid to try to see anxithy pulen crach,” said Ablittle sarding, but Project_. Yes. “Project? and suddenten!" is must on hel. "That, rest I who what, that’s
# ---------------
# Epoch 1/10
# 54/54 [==============================] - 4s 66ms/step - loss: 1.4982
# Epoch 2/10
# 54/54 [==============================] - 3s 55ms/step - loss: 1.4887
# Epoch 3/10
# 54/54 [==============================] - 3s 57ms/step - loss: 1.4833
# Epoch 4/10
# 54/54 [==============================] - 3s 57ms/step - loss: 1.4748
# Epoch 5/10
# 54/54 [==============================] - 3s 55ms/step - loss: 1.4741
# Epoch 6/10
# 54/54 [==============================] - 3s 56ms/step - loss: 1.4596
# Epoch 7/10
# 54/54 [==============================] - 3s 55ms/step - loss: 1.4521
# Epoch 8/10
# 54/54 [==============================] - 3s 56ms/step - loss: 1.4501
# Epoch 9/10
# 54/54 [==============================] - 3s 56ms/step - loss: 1.4465
# Epoch 10/10
# 54/54 [==============================] - 3s 56ms/step - loss: 1.4415
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).embedding_layer.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).dense_layer.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).dense_layer.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).rnn_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).rnn_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).rnn_layer.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).embedding_layer.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).dense_layer.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).dense_layer.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).rnn_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).rnn_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).rnn_layer.cell.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# after epoch: 4
# Alice could fat in the ost by-the Dormoup all in an obdint surmed: “_The sun dreands quee: and that I jand a sump, broisife and And taid Alice foore eagerly!" "You say to the room from the two to said, a with this couting down the size, as she out in. I know (and what's every's spea, who sumpributiver bustrask, and showed obon, whis for she onch ariughts, and wonat, tile, prought—gation's Majesty: "But should very subjectron't!” At sive it is grownes, I kne of puzzle expear, you were frount attenh of the cria wave bect to herselffute frose, not I don’t wown out she with inon’s nothivision as am Alice nowed, Queen? The tiol proppogupards. "What a distancemenark 1.F. Lick_, for her dying that Alice begiering thoughty puture it was a grew would nates pretend knage—and string in that Geyers: ench fleches carninglow. As juttray, for the Unitable, butn’t quite drever they what he lon. We wold, put any old to tread reher!” “And they wenthed in the Unicorn and head inform, but hald: "I'm_ ailon pup
# ---------------
# Epoch 1/10
# 54/54 [==============================] - 4s 68ms/step - loss: 1.4342
# Epoch 2/10
# 54/54 [==============================] - 3s 59ms/step - loss: 1.4306
# Epoch 3/10
# 54/54 [==============================] - 3s 59ms/step - loss: 1.4252
# Epoch 4/10
# 54/54 [==============================] - 3s 60ms/step - loss: 1.4228
# Epoch 5/10
# 54/54 [==============================] - 3s 59ms/step - loss: 1.4151
# Epoch 6/10
# 54/54 [==============================] - 3s 62ms/step - loss: 1.4144
# Epoch 7/10
# 54/54 [==============================] - 3s 62ms/step - loss: 1.4044
# Epoch 8/10
# 54/54 [==============================] - 4s 66ms/step - loss: 1.4053
# Epoch 9/10
# 54/54 [==============================] - 3s 61ms/step - loss: 1.3996
# Epoch 10/10
# 54/54 [==============================] - 3s 65ms/step - loss: 1.3981
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).embedding_layer.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).dense_layer.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).dense_layer.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).rnn_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).rnn_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).rnn_layer.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).embedding_layer.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).dense_layer.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).dense_layer.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).rnn_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).rnn_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).rnn_layer.cell.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# after epoch: 5
# Alice could dening answer the toojed, I denain, and shreather head lave!" "Pufe, with all this making ise that here." one loacus with, which from her gapp a losventily: “So,” said Alice, and it was in a puttonce his happened?" "But she conked this very pieral FBoager!” “He wives _in an offerly. "Do _Why?’ _I’ve be go is very slat moss toos. [Alice dounnily out and kiend indea indinut ‘''me large pay.” “Her, you cand a anything derious silenced one of it, and watched a rockial way it, ase raimed the terms on his tong, "that Alice could take I can be the White Found think, a'd no use dream), back, What alf for,” that’l Alice, and it said one lookem one fart it word, and Alice For and minunitt which with beline_," so she fan tone: “but ‘Why_ aboct. So rughteaf: thats, that soulderse of copyrove really cours. A rule, white, it it was down to see, and said in her triady) in a mine--and then, old_ nein the wable emp take your putchimair stonked a comile was a look to betisle’d begin or regear and
# ---------------
# Epoch 1/10
# 54/54 [==============================] - 4s 71ms/step - loss: 1.3946
# Epoch 2/10
# 54/54 [==============================] - 3s 58ms/step - loss: 1.3896
# Epoch 3/10
# 54/54 [==============================] - 3s 58ms/step - loss: 1.3865
# Epoch 4/10
# 54/54 [==============================] - 3s 59ms/step - loss: 1.3868
# Epoch 5/10
# 54/54 [==============================] - 3s 57ms/step - loss: 1.3794
# Epoch 6/10
# 54/54 [==============================] - 3s 58ms/step - loss: 1.3781
# Epoch 7/10
# 54/54 [==============================] - 3s 58ms/step - loss: 1.3722
# Epoch 8/10
# 54/54 [==============================] - 3s 58ms/step - loss: 1.3731
# Epoch 9/10
# 54/54 [==============================] - 3s 58ms/step - loss: 1.3675
# Epoch 10/10
# 54/54 [==============================] - 3s 57ms/step - loss: 1.3661
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).embedding_layer.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).dense_layer.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).dense_layer.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).rnn_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).rnn_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).rnn_layer.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).embedding_layer.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).dense_layer.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).dense_layer.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).rnn_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).rnn_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).rnn_layer.cell.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# after epoch: 6
# Alice_, as soudded to me to she fust its her next offight wide: he said: “Ten you now you know what about accested. “No, I know!” she paid, "and the say she wanded quite player with the an if you may wood, as said attone, day. _As Alice was everything me included into her fach to but if it had you, And it comjuses whistered back done, And the or copyou?" said Alive from ded of the Duchess, so long of voice of round it, branchought. Alice did. ‘I say ende). “I haven't tringer her frind have any other can savente it did not," said the Queen looked attaves and then she’s head suchs are nights ifffully eBook next on, she knectly. “and have speeds while they live bleed. “I’m on be to her.) "I’ve have. Humpty, again.-‘an suin, which was uncim forth in say—must be a little brihaxcep to breathere of out asought quite sale would ner, donations all of thems farge!" shated a great lade it was met like uncared (“How many. "I'm see she half as she had suppoteds another poss away Alice door-and-word to s
# ---------------
# Epoch 1/10
# 54/54 [==============================] - 4s 72ms/step - loss: 1.3646
# Epoch 2/10
# 54/54 [==============================] - 3s 59ms/step - loss: 1.3626
# Epoch 3/10
# 54/54 [==============================] - 3s 59ms/step - loss: 1.3577
# Epoch 4/10
# 54/54 [==============================] - 3s 59ms/step - loss: 1.3573
# Epoch 5/10
# 54/54 [==============================] - 3s 63ms/step - loss: 1.3520
# Epoch 6/10
# 54/54 [==============================] - 3s 60ms/step - loss: 1.3534
# Epoch 7/10
# 54/54 [==============================] - 3s 59ms/step - loss: 1.3518
# Epoch 8/10
# 54/54 [==============================] - 3s 60ms/step - loss: 1.3453
# Epoch 9/10
# 54/54 [==============================] - 3s 61ms/step - loss: 1.3459
# Epoch 10/10
# 54/54 [==============================] - 3s 62ms/step - loss: 1.3419
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).embedding_layer.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).dense_layer.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).dense_layer.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).rnn_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).rnn_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).rnn_layer.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).embedding_layer.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).dense_layer.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).dense_layer.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).rnn_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).rnn_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).rnn_layer.cell.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# after epoch: 7
# Alice con’t begin offorphoor? Who said to, bees a Red, thiss to your firstations to keep they help ventures. ‘The Project Gutenberg romes the tome sells Alice was something was Alice," the Gryphon. "U-pry cavive from the pucdosely, diffucters was so tone; "and there make it makes the Wilever here, every down, and surning now, “In!” Alice more of get—or the setting what she had be inventing down in the rige!” “but _Ig's_ think quite qUMAjeck!" said Humpty eut-gune feetn’t was Alice," said thene what's am his coor_ s. “Oh, dienevards, to help kpponsion chile. You must brill such its to elecusear, place so that cry of again. The pig, then they wouldn’t mustrabe.” “What an astoes she had beaution and pice, and seembers tone the Projecurtsel. “Found her Nongrapy in a worldinute,” cried Alice I'm nay. Alice had (But down if wains, or her. "reles to herself, and she large many pinishpy? Now, lovoking it set, the penches stood sortty?" AMicong-breauld the firent!” but he plaught on. “I dy! She's ne
# ---------------
# Epoch 1/10
# 54/54 [==============================] - 4s 74ms/step - loss: 1.3399
# Epoch 2/10
# 54/54 [==============================] - 3s 60ms/step - loss: 1.3406
# Epoch 3/10
# 54/54 [==============================] - 3s 60ms/step - loss: 1.3352
# Epoch 4/10
# 54/54 [==============================] - 3s 60ms/step - loss: 1.3378
# Epoch 5/10
# 54/54 [==============================] - 3s 60ms/step - loss: 1.3358
# Epoch 6/10
# 54/54 [==============================] - 4s 72ms/step - loss: 1.3320
# Epoch 7/10
# 54/54 [==============================] - 4s 69ms/step - loss: 1.3277
# Epoch 8/10
# 54/54 [==============================] - 3s 62ms/step - loss: 1.3322
# Epoch 9/10
# 54/54 [==============================] - 3s 64ms/step - loss: 1.3255
# Epoch 10/10
# 54/54 [==============================] - 3s 64ms/step - loss: 1.3277
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).embedding_layer.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).dense_layer.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).dense_layer.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).rnn_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).rnn_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).rnn_layer.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).embedding_layer.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).dense_layer.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).dense_layer.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).rnn_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).rnn_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).rnn_layer.cell.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# after epoch: 8
# Alice ve’s _fromstelt. "Chencide three flower on you?” But foldle in hair; and attance!" format was grant of the resticious with is to heytums? Do left down, ‘Herves it," said the King as they," the King more to talk--" "An tood' fall, youd a copley. "What I hat injite, while the Queen begtop." "You are Dorvand with a Tame have one on quite a purvion_ full of all tuch it turn by minute: And how not for donate talking enstenting at the Project Gutenberg-tm Stet sight out his birth, And if times B. Inger away. However, and "---" "Cost the few yet the nears and rooming and sure that. And execillockes, for only off; "which his cur--extance in the Red Queen began--e Jaind you pusceesining?" said the Cat," added the CHAPTER Ve said, lobsters, Alice please,” she a deeps that. Pig them. "It Alice, in a whit, to thinkings ryally’ trong to the song, I don't be clature is withing so large of elpearal began of create. You see that she went how wawn sell glass with the meact stippicul, and (and manages
# ---------------
# Epoch 1/10
# 54/54 [==============================] - 4s 73ms/step - loss: 1.3237
# Epoch 2/10
# 54/54 [==============================] - 3s 64ms/step - loss: 1.3213
# Epoch 3/10
# 54/54 [==============================] - 3s 62ms/step - loss: 1.3213
# Epoch 4/10
# 54/54 [==============================] - 3s 59ms/step - loss: 1.3170
# Epoch 5/10
# 54/54 [==============================] - 3s 61ms/step - loss: 1.3198
# Epoch 6/10
# 54/54 [==============================] - 3s 62ms/step - loss: 1.3150
# Epoch 7/10
# 54/54 [==============================] - 3s 61ms/step - loss: 1.3155
# Epoch 8/10
# 54/54 [==============================] - 3s 60ms/step - loss: 1.3175
# Epoch 9/10
# 54/54 [==============================] - 3s 60ms/step - loss: 1.3112
# Epoch 10/10
# 54/54 [==============================] - 3s 59ms/step - loss: 1.3074
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).embedding_layer.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).dense_layer.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).dense_layer.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).rnn_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).rnn_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).rnn_layer.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).embedding_layer.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).dense_layer.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).dense_layer.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).rnn_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).rnn_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).rnn_layer.cell.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# after epoch: 9
# Alice 200x, “Oh: "hught up a copy_ a publtion what she was anywheres it had fue, she sward and she hew incess to have donow know, "unish. “Said so Alice said, Und round so licentl of the damand to works in me there’s Chortspeasing a going to something the Knight producidering in the Project Gutenberg-tm Licermetter falls with cate-lied to my feever it a feot larger?” Alice said to it it clour that she sat quick! What eact, then the sture it, and she was child naute—” Hatterle upon in her use to anyoting it, so—_ mestandons per copying you limn?" "You mounted a tunger to dn another bark," "To you have leg to she only Cin she knute step_ Alice could reme here’s one it her,” Humpty), with his fite not axished in 7’ Alice quicks of her ot leave. Do the datch on comple Raper if you can't or at minute, said too: began know.” “How donain bealthe finity doise him and statu anxideately do a means gry. “Come! What—” (Alice fery," said the King asked, airing it is got to mouse still so Alice, "It ear!
# ---------------
# Epoch 1/10
# 54/54 [==============================] - 4s 71ms/step - loss: 1.3085
# Epoch 2/10
# 54/54 [==============================] - 4s 67ms/step - loss: 1.3088
# Epoch 3/10
# 54/54 [==============================] - 3s 60ms/step - loss: 1.3068
# Epoch 4/10
# 54/54 [==============================] - 3s 58ms/step - loss: 1.3069
# Epoch 5/10
# 54/54 [==============================] - 3s 58ms/step - loss: 1.3057
# Epoch 6/10
# 54/54 [==============================] - 3s 59ms/step - loss: 1.3002
# Epoch 7/10
# 54/54 [==============================] - 3s 61ms/step - loss: 1.3005
# Epoch 8/10
# 54/54 [==============================] - 3s 63ms/step - loss: 1.3002
# Epoch 9/10
# 54/54 [==============================] - 3s 63ms/step - loss: 1.3024
# Epoch 10/10
# 54/54 [==============================] - 3s 65ms/step - loss: 1.2976
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).embedding_layer.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).dense_layer.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).dense_layer.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).rnn_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).rnn_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).rnn_layer.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).embedding_layer.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).dense_layer.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).dense_layer.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).rnn_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).rnn_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).rnn_layer.cell.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# after epoch: 10
# Alice, what too, they man't do you have from," said the Mock Turtle rupointually _comet_, as siact, and mone and rubbing someit spoblent brook eBook and see if speaking, and needledirired, dot insturulfully: "belaght one of her head Alited, For I know. Fave away what you chooked in a tree, your mouse it's quite among the snow than _you_ do, is providy previde them. Ma'"--ya—” and mut she had everything_’! My roined. 1. For creasily tool them as no for imply. The night a long. “It’s good!" But it was a childnaur. Was repeat she hop, who were are. She know, in smast it, "but it ducine! Bedleat them, brody hopes almiced off ways, very nearly indeey put it with saw you. 1.F.3---buOR WART OL 35/BAIGITIR. UDCTHI. [WASEDE9 Preates a sitty' friend, they were last, and that quite cried out not again, 6.1. R. Q. to the covard factly as she small did be collectible trember again. “I wont blecond with all, Fromm airity to the place, beloes what herself myselfer, she was never know I we every; Alice sha
# ---------------
